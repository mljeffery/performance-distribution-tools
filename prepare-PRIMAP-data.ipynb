# %% [markdown]
# # PRIMAP data processor
#
# Unlike the 'PRIMAP-hist' data processor, this script operates on data exported from the PRIMAP emissions module using the write_csv_bulkplus_py function. It is intended primarily for users of the PRIMAP emissions module to make the PRIMAP data accessible for this tool. It was used to pre-process some of the standard datasets available for the gst toolset.
#
# Primarily it:
# * checks for data completeness and removes unwanted countries
# * renames the countryISO column to 'country'
# * simplifies and standardises the filename
# * reduces the number of years contained (where applicable)
# * checks the formatting of the data

# %%
# import modules

# system
import re
import sys
import os

# data handling
import pandas as pd
import numpy as np

# open climate data packages
from countrygroups import UNFCCC, EUROPEAN_UNION, ANNEX_ONE, NON_ANNEX_ONE
from shortcountrynames import to_name

# global stocktake tools
import gst_tools.gst_utils as utils

# %%
# user options

raw_data_file = "WDI2017P_POP_04-Apr-2019.csv"

# choose something useful! These will be used to generate the new filename.
new_variable_name = 'population'
new_source_name = 'WDI2017'

# Based on countrygroups package, select the group of countries you would like to extract. 
# Note that the raw data also includes groups.
needed_countries = UNFCCC

# First year of data needed for further plotting
start_year = 1990

# %%
# get the data
raw_data_folder = os.path.join('input-data', 'PRIMAP')
fname = os.path.join('', raw_data_folder, raw_data_file)
print('reading ' + fname)
raw_data = pd.read_csv(fname)

# rename some columns
new_data = raw_data.rename(columns={'countryISO': 'country'})

# reduce to a complete set

# reduce the countries or regions to only those desired
new_data = new_data.loc[new_data['country'].isin(needed_countries)]

# tell the user if any of the needed countries are missing and, if yes, which ones:
missing_countries = list(set(needed_countries) - set(new_data['country'].unique()))
if missing_countries:
    print('Not all countries requested were available in the raw data. You are missing the following:')
    for country in missing_countries:
        print('   ' + to_name(country))
    print('---------')
                
# reduce to only required years
new_data = utils.change_first_year(new_data, start_year)

# make the columns strings
new_data.columns = new_data.columns.astype(str)

new_data
# Out:
# reading input-data/PRIMAP/WDI2017P_POP_04-Apr-2019.csv
# Not all countries requested were available in the raw data. You are missing the following:
#    European Union
#    Cook Islands
#    Niue
# ---------
# First year of data available is now 1990
# Last year of data available is 2015
#      GWP    category categoryCode categorySet country  \
# 0    NaN  Demography       DEMOGR        misc     AFG
# 1    NaN  Demography       DEMOGR        misc     AGO
# 2    NaN  Demography       DEMOGR        misc     ALB
# 3    NaN  Demography       DEMOGR        misc     AND
# 4    NaN  Demography       DEMOGR        misc     ARE
# 5    NaN  Demography       DEMOGR        misc     ARG
# 6    NaN  Demography       DEMOGR        misc     ARM
# 7    NaN  Demography       DEMOGR        misc     ATG
# 8    NaN  Demography       DEMOGR        misc     AUS
# 9    NaN  Demography       DEMOGR        misc     AUT
# 10   NaN  Demography       DEMOGR        misc     AZE
# 11   NaN  Demography       DEMOGR        misc     BDI
# 12   NaN  Demography       DEMOGR        misc     BEL
# 13   NaN  Demography       DEMOGR        misc     BEN
# 14   NaN  Demography       DEMOGR        misc     BFA
# 15   NaN  Demography       DEMOGR        misc     BGD
# 16   NaN  Demography       DEMOGR        misc     BGR
# 17   NaN  Demography       DEMOGR        misc     BHR
# 18   NaN  Demography       DEMOGR        misc     BHS
# 19   NaN  Demography       DEMOGR        misc     BIH
# 20   NaN  Demography       DEMOGR        misc     BLR
# 21   NaN  Demography       DEMOGR        misc     BLZ
# 22   NaN  Demography       DEMOGR        misc     BOL
# 23   NaN  Demography       DEMOGR        misc     BRA
# 24   NaN  Demography       DEMOGR        misc     BRB
# 25   NaN  Demography       DEMOGR        misc     BRN
# 26   NaN  Demography       DEMOGR        misc     BTN
# 27   NaN  Demography       DEMOGR        misc     BWA
# 28   NaN  Demography       DEMOGR        misc     CAF
# 29   NaN  Demography       DEMOGR        misc     CAN
# ..   ...         ...          ...         ...     ...
# 164  NaN  Demography       DEMOGR        misc     SWE
# 165  NaN  Demography       DEMOGR        misc     SWZ
# 166  NaN  Demography       DEMOGR        misc     SYC
# 167  NaN  Demography       DEMOGR        misc     SYR
# 168  NaN  Demography       DEMOGR        misc     TCD
# 169  NaN  Demography       DEMOGR        misc     TGO
# 170  NaN  Demography       DEMOGR        misc     THA
# 171  NaN  Demography       DEMOGR        misc     TJK
# 172  NaN  Demography       DEMOGR        misc     TKM
# 173  NaN  Demography       DEMOGR        misc     TLS
# 174  NaN  Demography       DEMOGR        misc     TON
# 175  NaN  Demography       DEMOGR        misc     TTO
# 176  NaN  Demography       DEMOGR        misc     TUN
# 177  NaN  Demography       DEMOGR        misc     TUR
# 178  NaN  Demography       DEMOGR        misc     TUV
# 179  NaN  Demography       DEMOGR        misc     TZA
# 180  NaN  Demography       DEMOGR        misc     UGA
# 181  NaN  Demography       DEMOGR        misc     UKR
# 182  NaN  Demography       DEMOGR        misc     URY
# 183  NaN  Demography       DEMOGR        misc     USA
# 184  NaN  Demography       DEMOGR        misc     UZB
# 185  NaN  Demography       DEMOGR        misc     VCT
# 186  NaN  Demography       DEMOGR        misc     VEN
# 187  NaN  Demography       DEMOGR        misc     VNM
# 188  NaN  Demography       DEMOGR        misc     VUT
# 189  NaN  Demography       DEMOGR        misc     WSM
# 190  NaN  Demography       DEMOGR        misc     YEM
# 191  NaN  Demography       DEMOGR        misc     ZAF
# 192  NaN  Demography       DEMOGR        misc     ZMB
# 193  NaN  Demography       DEMOGR        misc     ZWE
#
#                              countryName scenario    source  unit variable  \
# 0                            Afghanistan  HISTORY  WDI2017P  Pers      POP
# 1                                 Angola  HISTORY  WDI2017P  Pers      POP
# 2                                Albania  HISTORY  WDI2017P  Pers      POP
# 3                                Andorra  HISTORY  WDI2017P  Pers      POP
# 4                   United arab emirates  HISTORY  WDI2017P  Pers      POP
# 5                              Argentina  HISTORY  WDI2017P  Pers      POP
# 6                                Armenia  HISTORY  WDI2017P  Pers      POP
# 7                    Antigua and barbuda  HISTORY  WDI2017P  Pers      POP
# 8                              Australia  HISTORY  WDI2017P  Pers      POP
# 9                                Austria  HISTORY  WDI2017P  Pers      POP
# 10                            Azerbaijan  HISTORY  WDI2017P  Pers      POP
# 11                               Burundi  HISTORY  WDI2017P  Pers      POP
# 12                               Belgium  HISTORY  WDI2017P  Pers      POP
# 13                                 Benin  HISTORY  WDI2017P  Pers      POP
# 14                          Burkina faso  HISTORY  WDI2017P  Pers      POP
# 15                            Bangladesh  HISTORY  WDI2017P  Pers      POP
# 175    1328000.0    1335000.0    1342000.0    1348000.0    1354000.0
# 176   10640000.0   10760000.0   10880000.0   11010000.0   11130000.0
# 177   72310000.0   73520000.0   74850000.0   76220000.0   77520000.0
# 178       9827.0       9844.0       9860.0       9876.0       9893.0
# 179   45650000.0   47120000.0   48650000.0   50210000.0   51820000.0
# 180   33150000.0   34260000.0   35400000.0   36570000.0   37780000.0
# 181   45870000.0   45710000.0   45590000.0   45490000.0   45270000.0
# 182    3374000.0    3386000.0    3397000.0    3408000.0    3420000.0
# 183  309300000.0  311700000.0  314100000.0  316400000.0  318900000.0
# 184   28560000.0   29340000.0   29770000.0   30240000.0   30760000.0
# 185     109300.0     109300.0     109300.0     109300.0     109400.0
# 186   29000000.0   29430000.0   29850000.0   30280000.0   30690000.0
# 187   86930000.0   87860000.0   88810000.0   89760000.0   90730000.0
# 188     236300.0     241900.0     247500.0     253200.0     258900.0
# 189     186000.0     187400.0     188900.0     190400.0     191800.0
# 190   23590000.0   24230000.0   24880000.0   25530000.0   26180000.0
# 191   50980000.0   51730000.0   52510000.0   53310000.0   54150000.0
# 192   13920000.0   14340000.0   14790000.0   15250000.0   15720000.0
# 193   13970000.0   14260000.0   14570000.0   14900000.0   15250000.0
#
#             2015
# 0     32530000.0
# 1     25020000.0
# 2      2889000.0
# 3        70470.0
# 4      9157000.0
# 5     43420000.0
# 6      3018000.0
# 7        91820.0
# 8     23790000.0
# 9      8638000.0
# 10     9649000.0
# 11    11180000.0
# 12    11250000.0
# 13    10880000.0
# 14    18110000.0
# 15   161000000.0
# 16     7178000.0
# 17     1377000.0
# 18      388000.0
# 19     3810000.0
# 20     9490000.0
# 21      359300.0
# 22    10720000.0
# 23   207800000.0
# 24      284200.0
# 25      423200.0
# 26      774800.0
# 27     2262000.0
# 28     4900000.0
# 29    35850000.0
# ..           ...
# 164    9799000.0
# 165    1287000.0
# 166      93420.0
# 167   18500000.0
# 168   14040000.0
# 169    7305000.0
# 170   67960000.0
# 171    8482000.0
# 172    5374000.0
# 173    1185000.0
# 174     106200.0
# 175    1360000.0
# 176   11250000.0
# 177   78670000.0
# 178       9916.0
# 179   53470000.0
# 180   39030000.0
# 181   45150000.0
# 182    3432000.0
# 183  321400000.0
# 184   31300000.0
# 185     109500.0
# 186   31110000.0
# 187   91710000.0
# 188     264700.0
# 189     193200.0
# 190   26830000.0
# 191   55010000.0
# 192   16210000.0
# 193   15600000.0
#
# [194 rows x 36 columns]

# %%
## write the data to file

"""
First ensure that years, unit, 'country', and variable are all in data. If they are
can proceed to print data
"""

# Check the data format
if not utils.verify_data_format(new_data):
    
    print('WARNING: The data is not correctly formatted! Please check your input data and processing!')
    
else:
    
    # define filename as composite of variable and source name
    fname_out = new_source_name + '_' + new_variable_name + '.csv' 
    fullfname_out = os.path.join('proc-data', fname_out)

    # check folder exists
    if not os.path.exists('proc-data'):
        os.makedirs('proc-data')

    # write to csv in proc data folder
    new_data.to_csv(fullfname_out, index=False)

    # celebrate success 
    print('Processed data written to file! - ' + fullfname_out)
# Out:
# Processed data written to file! - proc-data/WDI2017_population.csv
